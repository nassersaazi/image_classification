# %%
# !python3 --version
# Out:
# Python 3.6.9

# %%
# !pip3 install --upgrade tensorflow-hub
# Out:
# Requirement already up-to-date: tensorflow-hub in /usr/local/lib/python3.6/dist-packages
# Requirement already up-to-date: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-hub)
# Requirement already up-to-date: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-hub)
# Requirement already up-to-date: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-hub)
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-hub)

# %%
# !./train.bash
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !ls
# Out:
# assets		label_image.py	test2.jpg  test_accuracy_2.py
# burger.png	predict.bash	test3.jpg  tools
# data		retrain.py	test4.jpg  train.bash
# food101.md	test.jpg	test5.jpg  transfer_learning_model.ipynb
# label_image.md	test1.jpg	test6.jpg

# %%
# !./predict.bash test.jpg
# Out:
# cbsd 0.5867168
# cbb 0.3335304
# cgm 0.06575181
# cmd 0.00901701
# healthy 0.0049840827

# %%
# !./predict.bash test2.jpg
# Out:
# cbsd 0.75129443
# cbb 0.19681726
# cmd 0.033089347
# healthy 0.010058623
# cgm 0.008740392

# %%
# !./predict.bash test3.jpg
# Out:
# cbsd 0.7123589
# cbb 0.22279346
# healthy 0.03900078
# cmd 0.019059043
# cgm 0.006787801

# %%
# !./predict.bash test4.jpg
# Out:
# cgm 0.9638356
# cbb 0.019891607
# healthy 0.009733131
# cmd 0.004073643
# cbsd 0.0024660262

# %%
# !./predict.bash test6.jpg
# Out:
# cgm 0.95931554
# cbb 0.022979213
# cmd 0.015801422
# cbsd 0.0017724097
# healthy 0.00013151298

# %%
# !./predict.bash test5.jpg
# Out:
# cbsd 0.7123589
# cbb 0.22279346
# healthy 0.03900078
# cmd 0.019059043
# cgm 0.006787801

# %%
# !./predict.bash burger.png
# Out:
# cbb 0.56286204
# cmd 0.3192295
# cbsd 0.094368935
# cgm 0.018305037
# healthy 0.0052344515

# %%
# !./predict.bash test1.jpg
# Out:
# healthy 0.64592934
# cbsd 0.20428604
# cbb 0.13720508
# cmd 0.010407352
# cgm 0.0021722259
